# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import signal

data = pd.read_csv('test2.csv', header=None, index_col=False)
result = data.transpose()
print(len(result))
result = result[0:1000]
print(result[0:1000])
# Out:
# 2000
#         0     1
# 0       5  1931
# 1      10  1360
# 2      15  1946
# 3      20  1461
# 4      25  1553
# ..    ...   ...
# 995  4980  1215
# 996  4985  1082
# 997  4990  1671
# 998  4995  1648
# 999  5000  1741
#
# [1000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(result[0], result[1])

# %%
from numpy import genfromtxt
my_data = genfromtxt('test2.csv', delimiter = ',')
print(my_data[0])
plt.plot(my_data[1][0:1000])
# Out:
# [5.000e+00 1.000e+01 1.500e+01 ... 9.990e+03 9.995e+03 1.000e+04]

# %%
b, a = signal.butter(5, 0.5)

# zi = signal.lfilter_zi(b, a)

y = signal.filtfilt(b, a, my_data[1][1000:2000])

plt.plot(y)
